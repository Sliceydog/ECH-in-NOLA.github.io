# %% [markdown]
# # Project Plan

# %% [markdown]
# ## renarepenning.github.io

# %% [markdown]
# **Data Sets:**
# 1. We Play Data ^1
#     Provided by Christine Neely
# 2. Dibels Reading Report" PDF
#     https://www.louisianabelieves.com/docs/default-source/test-results/fall-2020-dibels-reading-report.pdf?sfvrsn=28a96618_8
# 3. 2018-2020 PK-5 enrollment data (xlsx)
#     https://www.louisianabelieves.com/docs/default-source/believe/k-enrollment-trends.pdf?sfvrsn=6eca6718_6
#
# **Possible others**
# 1. https://www.louisianaschools.com/
#    Early childhood education centers in New Orleans, by age group.
# 2. https://opennola.org/state-of-the-young-child-in-new-orleans-edi-neighborhood-profiles/
#    "STATE OF THE YOUNG CHILD IN NEW ORLEANS: EDI NEIGHBORHOOD PROFILES"
#     This Dataset measures five areas of early childhood development to classify Kindergarten readiness. These include "Physical health and wellbeing", "Social competence", "Emotional Maturity", "Language and cognitive skills", and "Communication skills and general knowledge".
#     ^2
#
# We are inspired by The We Play center's mission: "to offer a safe place to play while engaging in activities that promote brain development."
# Melanie Richardson expressed a need for statistical evidence of We Play's importance.
# Although we would like to use the center's existing data, it doesn't have consistent ids per unit of observation. This prohibits us from studying participent's
# educational or well-being outcomes.
# Also, Christine Neely sent us sporadic data from the past two years. We cannot analyze
# change over uneven time periods.
# Instead of analyzing WePlay's surveys, we would like to validate the center's work by illustrating social impact.
#
# Children in Louisiana were not required to attend kindergarten until June of 2021.
# Studies show that children who cannot read at grade level by the third grade will lag behind for the rest of their education.^3
# We hypothesize that access to early childhood education will greatly improve a child's literacy by the third grade.
# "2018-2020 PK-5 Enrollment" provides reading test results, but it is in PDF form so will need to be transfered to a CSV
# manually or parsed as a PDF.
# We aim to analyze early childhood education availability's impact on elementary school reading proficiency.
# Additonally, we would like to look at center availability and need.
# Once we establish a quantifiable need for early childhood education we can analyze inhibiting factors
# by scraping data on all centers in Louisiana.
# "State of the young child..." applies to our hypothesis and could possible be of use if we have time to analyze multiple questions.
#
# ^1 WePLAY data was last downloaded on October 25th, 2021. We could not use a live link because of spaces in filenames.
#
# ^2 This site's links are broken so we are awaiting response. Will call if they haven't responded by 10/27.
#
# ^3 https://news.yahoo.com/kindergarten-required-louisiana-edwards-signs-230000296.html
#
#
# **Collaboration Plan:**
# Rena and Eddy will utilize this repository to simultaneously edit the project.
# We plan on connecting over Zoom as needed and keeping constant communication over instant message. Also, we are both able to meet after class on Thursdays.
# When convinient, we will export notebooks to Google Colabs to support simultaneous editing.
# (This is easily done using a Colabs Chrome extension).

# %% [markdown]
# # Exploring WePlay survey results

# %% [markdown]
# Provided by Christine Neely from WePlay by Training Grounds nola. Data last accessed on October 25th.

# %%
import pandas as pd

## Imports, as needed
#!head ../notebooks/_data/WePLAYData/
#!pip3 install openpyxl # followed error messages to install openpyxl package

# %%
fam_survey = pd.read_excel("../notebooks/_data/WePlayData/WPCFamilySurvey.xlsx")
fam_survey.head()

## This dataset has many more values than entries, and cannot be effectively tidied as the key is Respondent ID
# Out:
#    Respondent ID  Collector ID          Start Date            End Date  \
# 0            NaN           NaN                 NaT                 NaT
# 1   1.092363e+10   225003849.0 2019-08-13 14:16:22 2019-08-13 14:20:25
# 2   1.092340e+10   225003849.0 2019-08-13 12:43:30 2019-08-13 12:52:16
# 3   1.092099e+10   225003849.0 2019-08-12 12:27:33 2019-08-12 12:34:37
# 4   1.092099e+10   225003849.0 2019-08-12 11:48:15 2019-08-12 12:26:53
#
#       IP Address  Email Address  First Name  Last Name  Custom Data 1  \
# 0            NaN            NaN         NaN        NaN            NaN
# 1  107.77.249.48            NaN         NaN        NaN            NaN
# 2   172.56.26.76            NaN         NaN        NaN            NaN
# 3  107.77.249.48            NaN         NaN        NaN            NaN
# 4  107.77.249.48            NaN         NaN        NaN            NaN
#
#   What is your gender?  ...  \
# 0             Response  ...
# 1               Female  ...
# 2               Female  ...
# 3               Female  ...
# 4               Female  ...
#
#                                          Unnamed: 64  \
# 0  Has your child exhibited an increase in age-ap...
# 1                                       Mostly agree
# 2                                                NaN
# 3                         Neither disagree nor agree
# 4                                                NaN
#
#   In a typical week, about how much time does your child engage in active indoor play?  \
# 0                                Hours (approximate)
# 1                                                NaN
# 2                                                  7
# 3                                                 12
# 4                                                NaN
#
#   In a typical week, about how much time does your child engage in quiet indoor play?  \
# 0                                Hours (approximate)
# 1                                                NaN
# 2                                                  5
# 3                                                 12
# 4                                                NaN
#
#   In a typical week, about how much time does your child engage in outdoor play?  \
# 0                                Hours (approximate)
# 1                                                NaN
# 2                                                  7
# 3                                                  3
# 4                                                NaN
#
#   What will keep you coming back to the We PLAY Center?  \
# 0                                Open-Ended Response
# 1                                                NaN
# 2       The positive staff and positive environment.
# 3  My kids love it there an I enjoy playing with ...
# 4                                                NaN
#
#   What aspect of the We PLAY Center do you find most helpful?  \
# 0                                Open-Ended Response
# 1                                                NaN
# 2                                                NaN
# 3                                    Different stuff
# 4                                                NaN
#
#   Would you recommend a family or friend to the We PLAY Center?          Name  \
# 0                                           Response               First Name
# 1                                                NaN                      NaN
# 2                                                Yes             Xontownekiah
# 3                                                Yes                    Megan
# 4                                                NaN                      NaN
#
#   Unnamed: 72        Date
# 0   Last Name        Date
# 1         NaN         NaN
# 2     Ellison  08/13/2019
# 3      Nelson  08/12/2019
# 4         NaN         NaN
#
# [5 rows x 74 columns]

# %%
# This set has the same issues
incoming_reflection = pd.read_excel("../notebooks/_data/WePlayData/WPCIncomingParentReflection.xlsx")
incoming_reflection.head()
# Out:
#    Respondent ID  Collector ID          Start Date            End Date  \
# 0            NaN           NaN                 NaT                 NaT
# 1   1.127194e+10   244233757.0 2020-01-13 17:42:45 2020-01-13 18:19:24
# 2   1.123680e+10   244233757.0 2019-12-20 11:38:37 2019-12-20 11:43:06
# 3   1.123251e+10   244233757.0 2019-12-18 15:03:02 2019-12-18 15:06:43
# 4   1.117937e+10   244233757.0 2019-11-27 15:07:54 2019-11-27 15:11:54
#
#        IP Address  Email Address  First Name  Last Name  Custom Data 1  \
# 0             NaN            NaN         NaN        NaN            NaN
# 1  98.163.225.126            NaN         NaN        NaN            NaN
# 2    70.186.98.87            NaN         NaN        NaN            NaN
# 3  72.211.124.135            NaN         NaN        NaN            NaN
# 4   107.77.200.18            NaN         NaN        NaN            NaN
#
#   What is your gender?  ... Unnamed: 122  \
# 0             Response  ...      Website
# 1               Female  ...          NaN
# 2               Female  ...          NaN
# 3                 Male  ...          NaN
# 4               Female  ...          NaN
#
#                                   Unnamed: 123  \
# 0  Social Media (facebook, Twitter, Instagram)
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#                                         Unnamed: 124  \
# 0  Another organization (Kingsley House, Healthy ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                      Unnamed: 125          Unnamed: 126  \
# 0  Lafitte Fauborg Housing Office  We PLAY Center Staff
# 1                             NaN                   NaN
# 2                             NaN                   NaN
# 3                             NaN                   NaN
# 4                             NaN                   NaN
#
#                                         Unnamed: 127  \
# 0                             Other (please specify)
# 1  From picking up School Supplies for my other 2...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Would you recommend the We PLAY Center to a family or friend?  \
# 0                                           Response
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Are there any additional comments you would like to share with the We PLAY Center?  \
# 0                                Open-Ended Response
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                      Please open on the weekends!
#
#           First Name.1          Last Name.1
# 0  Open-Ended Response  Open-Ended Response
# 1                Stacy               Harris
# 2              Jessica              Winters
# 3              Oliver                  Wise
# 4                Megan              Washack
#
# [5 rows x 132 columns]

# %%
incoming_reflection_July19 = pd.read_excel("../notebooks/_data/WePlayData/WPCIncomingParentReflection-July2019.xlsx")
incoming_reflection_July19.head()
# Out:
#    Respondent ID  Collector ID          Start Date            End Date  \
# 0            NaN           NaN                 NaT                 NaT
# 1   1.097254e+10   242461998.0 2019-09-05 18:11:49 2019-09-05 18:24:24
# 2   1.093646e+10   242461998.0 2019-08-20 07:09:08 2019-08-20 07:22:17
# 3   1.091339e+10   242461998.0 2019-08-08 11:44:40 2019-08-08 11:58:47
# 4   1.091316e+10   242884281.0 2019-08-08 10:33:01 2019-08-08 10:44:29
#
#       IP Address Email Address  First Name  Last Name  Custom Data 1  \
# 0            NaN           NaN         NaN        NaN            NaN
# 1  63.249.72.114           NaN         NaN        NaN            NaN
# 2  72.211.114.28           NaN         NaN        NaN            NaN
# 3  72.204.146.32           NaN         NaN        NaN            NaN
# 4  72.205.182.40           NaN         NaN        NaN            NaN
#
#   What is your gender?  ... Unnamed: 163  \
# 0             Response  ...      Website
# 1               Female  ...          NaN
# 2               Female  ...          NaN
# 3               Female  ...          NaN
# 4                 Male  ...      Website
#
#                                   Unnamed: 164  \
# 0  Social Media (facebook, Twitter, Instagram)
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4  Social Media (facebook, Twitter, Instagram)
#
#                                         Unnamed: 165  \
# 0  Another organization (Kingsley House, Healthy ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                      Unnamed: 166            Unnamed: 167  \
# 0  Lafitte Fauborg Housing Office  Other (please specify)
# 1                             NaN                     NaN
# 2                             NaN                     NaN
# 3                             NaN                     NaN
# 4                             NaN                     NaN
#
#   Would you recommend the We PLAY Center to a family or friend?  \
# 0                                           Response
# 1                                                NaN
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Do you have any feedback on how the We PLAY Center can improve this Parent Reflection Form?  Your feedback will used to modify this form and guide the development of future forms.  \
# 0                                Open-Ended Response
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Are there any additional comments you would like to share with the We PLAY Center?  \
# 0                                Open-Ended Response
# 1                                                NaN
# 2  You all have been such an important and valuab...
# 3  You all are the best! The staff is amazing. I’...
# 4                                                NaN
#
#           First Name.1          Last Name.1
# 0  Open-Ended Response  Open-Ended Response
# 1                  NaN                  NaN
# 2               Deidre                Gantt
# 3                Annie            Miklavcic
# 4                 John               Abadie
#
# [5 rows x 173 columns]

# %%
incoming_reflection_Nov19 = pd.read_excel("../notebooks/_data/WePlayData/WPCIncomingParentReflection-November2019.xlsx")
incoming_reflection_Nov19.head()
# Out:
#    Respondent ID  Collector ID          Start Date            End Date  \
# 0            NaN           NaN                 NaT                 NaT
# 1   1.121566e+10   249828299.0 2019-12-11 18:52:26 2019-12-11 19:28:39
# 2   1.120736e+10   249828299.0 2019-12-09 10:28:23 2019-12-09 10:35:47
# 3   1.118977e+10   249828299.0 2019-12-02 16:37:16 2019-12-02 16:45:41
# 4   1.116087e+10   248173257.0 2019-11-20 14:44:16 2019-11-20 14:46:17
#
#        IP Address              Email Address  First Name  Last Name  \
# 0             NaN                        NaN         NaN        NaN
# 1   70.180.70.217      raklasing58@gmail.com         NaN        NaN
# 2  99.203.155.230  christopherbenz@gmail.com         NaN        NaN
# 3  72.198.183.180   joanna.x.russo@gmail.com         NaN        NaN
# 4   172.58.101.23                        NaN         NaN        NaN
#
#    Custom Data 1 What is your gender?  ...  \
# 0            NaN             Response  ...
# 1            NaN               Female  ...
# 2            NaN                 Male  ...
# 3            NaN               Female  ...
# 4            NaN               Female  ...
#
#                                   Unnamed: 170  \
# 0  Social Media (facebook, Twitter, Instagram)
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#                                         Unnamed: 171  \
# 0  Another organization (Kingsley House, Healthy ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                      Unnamed: 172          Unnamed: 173  \
# 0  Lafitte Fauborg Housing Office  We PLAY Center Staff
# 1                             NaN                   NaN
# 2                             NaN                   NaN
# 3                             NaN                   NaN
# 4                             NaN                   NaN
#
#              Unnamed: 174  \
# 0  Other (please specify)
# 1              Dcfs staff
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
#   Would you recommend the We PLAY Center to a family or friend?  \
# 0                                           Response
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                NaN
#
#   Do you have any feedback on how the We PLAY Center can improve this Parent Reflection Form?  Your feedback will used to modify this form and guide the development of future forms.  \
# 0                                Open-Ended Response
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Are there any additional comments you would like to share with the We PLAY Center?  \
# 0                                Open-Ended Response
# 1                                                NaN
# 2                               Thanks for existing!
# 3                                                NaN
# 4                                                NaN
#
#           First Name.1          Last Name.1
# 0  Open-Ended Response  Open-Ended Response
# 1             Roberta              Klasing
# 2          christopher                 benz
# 3                  NaN                  NaN
# 4                  NaN                  NaN
#
# [5 rows x 180 columns]

# %%
incoming_reflection2020 = pd.read_excel("../notebooks/_data/WePlayData/CopyofTheWePLAYCenterIncomingParentReflectionForm2020.xlsx")
incoming_reflection2020.head()
# Out:
#    Respondent ID  Collector ID          Start Date            End Date  \
# 0            NaN           NaN                 NaT                 NaT
# 1   1.139259e+10   252542815.0 2020-03-04 14:30:44 2020-03-04 14:37:00
# 2   1.136253e+10   252542815.0 2020-02-21 10:46:37 2020-02-21 10:49:59
# 3   1.135788e+10   252542815.0 2020-02-19 16:33:15 2020-02-19 16:38:13
# 4   1.135497e+10   252542815.0 2020-02-18 16:11:12 2020-02-18 16:35:56
#
#         IP Address  Email Address  First Name  Last Name  Custom Data 1  \
# 0              NaN            NaN         NaN        NaN            NaN
# 1    99.203.26.135            NaN         NaN        NaN            NaN
# 2   72.211.115.231            NaN         NaN        NaN            NaN
# 3  184.176.223.214            NaN         NaN        NaN            NaN
# 4    98.164.79.160            NaN         NaN        NaN            NaN
#
#   What is your gender?  ... Unnamed: 122  \
# 0             Response  ...      Website
# 1               Female  ...          NaN
# 2               Female  ...          NaN
# 3               Female  ...          NaN
# 4               Female  ...          NaN
#
#                                   Unnamed: 123  \
# 0  Social Media (facebook, Twitter, Instagram)
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#                                         Unnamed: 124  \
# 0  Another organization (Kingsley House, Healthy ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                      Unnamed: 125          Unnamed: 126  \
# 0  Lafitte Fauborg Housing Office  We PLAY Center Staff
# 1                             NaN                   NaN
# 2                             NaN                   NaN
# 3                             NaN                   NaN
# 4                             NaN                   NaN
#
#              Unnamed: 127  \
# 0  Other (please specify)
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
#   Would you recommend the We PLAY Center to a family or friend?  \
# 0                                           Response
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                NaN
#
#   Are there any additional comments you would like to share with the We PLAY Center?  \
# 0                                Open-Ended Response
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#           First Name.1          Last Name.1
# 0  Open-Ended Response  Open-Ended Response
# 1                Siera               Tafoya
# 2                  NaN                  NaN
# 3                Lydia              Nichols
# 4                  NaN                  NaN
#
# [5 rows x 132 columns]

# %% [markdown]
# There are no key overlaps within the datasets so we cannot use a person as the unit of observation. We can only do some basic demographic data.

# %% [markdown]
# # # Looking at PK-K Enrollment data

# %% [markdown]
# 2018-2020 PK-5 enrollment data taken from louisianabelieves.com, last accessed October 25th
#
# In progress of tidying this data correctly....
#
# We plan to use the data to illustrate PK/K enrollment per parish.
# (Kindergarten was not mandatory until 2021)

# %%
enrollmentDF = pd.read_excel("../notebooks/_data/pk-5enrollmentdata.xlsx")
enrollmentDF.head()
# Out:
#                                           Unnamed: 0          Unnamed: 1  \
# 0  PreK - Grade 5 Enrollment Percent Change by To...                 NaN
# 1                                      School System  School System Name
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4                                                 LA               State
#
#                Unnamed: 2 Unnamed: 3 Unnamed: 4              Unnamed: 5  \
# 0                     NaN        NaN        NaN                     NaN
# 1          Percent Change        NaN        NaN                     NaN
# 2  Fall 2019 to Fall 2020        NaN        NaN  Fall 2018 to Fall 2019
# 3                    PreK          K     Gr 1-5                    PreK
# 4               -0.174036  -0.074355  -0.041914                -0.00562
#
#   Unnamed: 6 Unnamed: 7         Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN                NaN        NaN         NaN         NaN
# 1        NaN        NaN  Enrollment Counts        NaN         NaN         NaN
# 2        NaN        NaN          Fall 2020        NaN         NaN   Fall 2019
# 3          K     Gr 1-5               PreK          K      Gr 1-5        PreK
# 4   0.022907  -0.008936              23089      49933      254371       27954
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN   Fall 2018         NaN         NaN
# 3           K      Gr 1-5        PreK           K      Gr 1-5
# 4       53944      265499       28112       52736      267893

# %%
parish = enrollmentDF.iloc[4:, 1]
enrollment = enrollmentDF.iloc[2:, 8:]
#enrollment = enrollment.to_frame()

# %%
enrollment["Parish"] = parish

#enrollment.drop(columns=[10, 13, 16], axis=1)
enrollment
# Out:
#    Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 2   Fall 2020        NaN         NaN   Fall 2019         NaN         NaN
# 3        PreK          K      Gr 1-5        PreK           K      Gr 1-5
# 4       23089      49933      254371       27954       53944      265499
# 5         363        812        3661         396         817        3721
# 6         245        289        1496         238         311        1548
# ..        ...        ...         ...         ...         ...         ...
# 75          0          0           0           0           2           3
# 76        201       1933       10423         247        1864       10388
# 77       1085       2753       14793        1576        3300       17211
# 78         40        102         701          39         131         774
# 79         30        102         545          30         113         562
#
#    Unnamed: 14 Unnamed: 15 Unnamed: 16                                  Parish
# 2    Fall 2018         NaN         NaN                                     NaN
# 3         PreK           K      Gr 1-5                                     NaN
# 4        28112       52736      267893                                   State
# 5          397         786        3744                           Acadia Parish
# 6          239         350        1570                            Allen Parish
# ..         ...         ...         ...                                     ...
# 75           0           0           2      Louisiana Special Education Center
# 76         256        1854       10411                         Type 2 Charters
# 77        1527        3177       17096                          Orleans Parish
# 78          38         147         804  Recovery School District - Baton Rouge
# 79          20         130         559    Recovery School District - Louisiana
#
# [78 rows x 10 columns]

# %% [markdown]
# Pivoting data -- Format TBD

# %%
# Plan to drop colums w/ 1-5, add columns for date and age, etc


# enrollment.pivot_table(
#     index="Parish", columns=["Period", "Age"],
#     values="rate"
# )
